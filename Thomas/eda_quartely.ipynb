# %%
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('../data/data_input_quarterly.csv')

# %%
sns.lineplot(data=df[df["iso2"] == "SE"].dropna(subset=["totalCreditPnfsLCY"]),x='date', y="cpi_yoy")
# Out:
# c:\Users\Thoma\.conda\envs\eui\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Thoma\.conda\envs\eui\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='date', ylabel='cpi_yoy'>

# %%
sns.boxplot(data=df[df["cpi_yoy"]<50], x='iso2', y='cpi_yoy')
# Out:
# <Axes: xlabel='iso2', ylabel='cpi_yoy'>

# %%
sns.boxplot(data=df.dropna(subset=["bankCreditPnfs"]), x='iso2', y='bankCreditPnfs')
# Out:
# <Axes: xlabel='iso2', ylabel='bankCreditPnfs'>

# %%
sns.boxplot(data=df.dropna(subset=["totalCreditPnfsLCY"]), x='iso2', y='totalCreditPnfsLCY')
# Out:
# <Axes: xlabel='iso2', ylabel='totalCreditPnfsLCY'>

# %%
sns.lineplot(data=df[df["iso2"] == "HU"].dropna(subset=["totalCreditPnfsLCY"]),x='date', y="totalCreditPnfsLCY")
# Out:
# c:\Users\Thoma\.conda\envs\eui\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\Thoma\.conda\envs\eui\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='date', ylabel='totalCreditPnfsLCY'>

# %%
df[df["iso2"] == "HU"]
# Out:
#       iso2     date  loansPnfs_yoy  resPropPrice   cpi_yoy          fx  \
# 11448   HU  1949-01            NaN           NaN       NaN   11.740000
# 11449   HU  1949-02            NaN           NaN       NaN   11.740000
# 11450   HU  1949-03            NaN           NaN       NaN   11.740000
# 11451   HU  1949-04            NaN           NaN       NaN   11.740000
# 11452   HU  1949-05            NaN           NaN       NaN   11.740000
# ...    ...      ...            ...           ...       ...         ...
# 12349   HU  2024-02            NaN           NaN  3.663790  359.250408
# 12350   HU  2024-03            NaN           NaN  3.634824  363.410701
# 12351   HU  2024-04            NaN           NaN  3.660776  365.818529
# 12352   HU  2024-05            NaN           NaN       NaN  358.109773
# 12353   HU  2024-06            NaN           NaN       NaN  361.003505
#
#        totalCreditPnfs2GDP  totalCreditPnfsLCY  dsrPnfs  dsrHousehold_x  \
# ...
